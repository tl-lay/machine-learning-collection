# %% [markdown]
# # Seq2Seq Learning in Keras - English to French Translation
#
# https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html

# %%
# importing libraries
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Model
from keras.layers import Input, LSTM, Dense

# %%
# configurations
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = "fra.txt"

# %% [markdown]
# ## Downloading the Data

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip
# Out:
# ['Archive:  fra-eng.zip',
#  'replace _about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y',
#  '  inflating: _about.txt              ',
#  'replace fra.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: y',
#  '  inflating: fra.txt                 ']

# %% [markdown]
# ## Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)

input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %% [markdown]
# ## Build the Model

# %%
# Define an input sequence and process it.
encoder_inputs = keras.Input(shape=(None, num_encoder_tokens))
encoder = keras.layers.LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = keras.Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = keras.layers.LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = keras.layers.Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = keras.Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# ## Train the Model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 7s 23ms/step - loss: 1.2079 - accuracy: 0.7321 - val_loss: 1.1317 - val_accuracy: 0.6999
# Epoch 2/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.9371 - accuracy: 0.7485 - val_loss: 0.9601 - val_accuracy: 0.7336
# Epoch 3/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.8447 - accuracy: 0.7671 - val_loss: 0.8751 - val_accuracy: 0.7493
# Epoch 4/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.7490 - accuracy: 0.7902 - val_loss: 0.7771 - val_accuracy: 0.7772
# Epoch 5/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.6962 - accuracy: 0.8019 - val_loss: 0.7263 - val_accuracy: 0.7885
# Epoch 6/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.6358 - accuracy: 0.8159 - val_loss: 0.6888 - val_accuracy: 0.8013
# Epoch 7/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.6058 - accuracy: 0.8229 - val_loss: 0.6611 - val_accuracy: 0.8074
# Epoch 8/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.5823 - accuracy: 0.8289 - val_loss: 0.6309 - val_accuracy: 0.8152
# Epoch 9/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5608 - accuracy: 0.8355 - val_loss: 0.6152 - val_accuracy: 0.8235
# Epoch 10/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5425 - accuracy: 0.8411 - val_loss: 0.5963 - val_accuracy: 0.8268
# Epoch 11/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5260 - accuracy: 0.8455 - val_loss: 0.5758 - val_accuracy: 0.8329
# Epoch 12/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.5115 - accuracy: 0.8497 - val_loss: 0.5657 - val_accuracy: 0.8342
# Epoch 13/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4969 - accuracy: 0.8543 - val_loss: 0.5553 - val_accuracy: 0.8381
# Epoch 14/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4840 - accuracy: 0.8576 - val_loss: 0.5417 - val_accuracy: 0.8424
# Epoch 15/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4727 - accuracy: 0.8608 - val_loss: 0.5311 - val_accuracy: 0.8458
# Epoch 16/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4621 - accuracy: 0.8633 - val_loss: 0.5201 - val_accuracy: 0.8493
# Epoch 17/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4526 - accuracy: 0.8665 - val_loss: 0.5134 - val_accuracy: 0.8504
# Epoch 18/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4434 - accuracy: 0.8690 - val_loss: 0.5045 - val_accuracy: 0.8527
# Epoch 19/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4345 - accuracy: 0.8714 - val_loss: 0.4976 - val_accuracy: 0.8553
# Epoch 20/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4261 - accuracy: 0.8736 - val_loss: 0.4936 - val_accuracy: 0.8556
# Epoch 21/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.4193 - accuracy: 0.8755 - val_loss: 0.4897 - val_accuracy: 0.8563
# Epoch 22/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4116 - accuracy: 0.8774 - val_loss: 0.4833 - val_accuracy: 0.8585
# Epoch 23/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.4045 - accuracy: 0.8795 - val_loss: 0.4836 - val_accuracy: 0.8582
# Epoch 24/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3981 - accuracy: 0.8812 - val_loss: 0.4769 - val_accuracy: 0.8608
# Epoch 25/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3920 - accuracy: 0.8831 - val_loss: 0.4691 - val_accuracy: 0.8621
# Epoch 26/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3856 - accuracy: 0.8850 - val_loss: 0.4655 - val_accuracy: 0.8627
# Epoch 27/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3799 - accuracy: 0.8866 - val_loss: 0.4656 - val_accuracy: 0.8635
# Epoch 28/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3741 - accuracy: 0.8884 - val_loss: 0.4582 - val_accuracy: 0.8658
# Epoch 29/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3686 - accuracy: 0.8899 - val_loss: 0.4550 - val_accuracy: 0.8667
# Epoch 30/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.3633 - accuracy: 0.8914 - val_loss: 0.4554 - val_accuracy: 0.8660
# Epoch 31/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3580 - accuracy: 0.8931 - val_loss: 0.4497 - val_accuracy: 0.8679
# Epoch 32/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3524 - accuracy: 0.8947 - val_loss: 0.4502 - val_accuracy: 0.8677
# Epoch 33/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3475 - accuracy: 0.8962 - val_loss: 0.4457 - val_accuracy: 0.8700
# Epoch 34/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3429 - accuracy: 0.8975 - val_loss: 0.4418 - val_accuracy: 0.8701
# Epoch 35/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3377 - accuracy: 0.8992 - val_loss: 0.4435 - val_accuracy: 0.8706
# Epoch 36/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3333 - accuracy: 0.9004 - val_loss: 0.4388 - val_accuracy: 0.8715
# Epoch 37/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3283 - accuracy: 0.9017 - val_loss: 0.4397 - val_accuracy: 0.8714
# Epoch 38/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3240 - accuracy: 0.9031 - val_loss: 0.4350 - val_accuracy: 0.8729
# Epoch 39/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3192 - accuracy: 0.9047 - val_loss: 0.4350 - val_accuracy: 0.8735
# Epoch 40/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3151 - accuracy: 0.9057 - val_loss: 0.4368 - val_accuracy: 0.8736
# Epoch 41/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3107 - accuracy: 0.9070 - val_loss: 0.4322 - val_accuracy: 0.8749
# Epoch 42/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3065 - accuracy: 0.9082 - val_loss: 0.4350 - val_accuracy: 0.8750
# Epoch 43/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3024 - accuracy: 0.9094 - val_loss: 0.4332 - val_accuracy: 0.8752
# Epoch 44/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2981 - accuracy: 0.9106 - val_loss: 0.4328 - val_accuracy: 0.8749
# Epoch 45/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2939 - accuracy: 0.9121 - val_loss: 0.4341 - val_accuracy: 0.8751
# Epoch 46/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2901 - accuracy: 0.9129 - val_loss: 0.4343 - val_accuracy: 0.8757
# Epoch 47/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2863 - accuracy: 0.9143 - val_loss: 0.4312 - val_accuracy: 0.8767
# Epoch 48/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2822 - accuracy: 0.9154 - val_loss: 0.4326 - val_accuracy: 0.8768
# Epoch 49/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2786 - accuracy: 0.9164 - val_loss: 0.4328 - val_accuracy: 0.8761
# Epoch 50/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2747 - accuracy: 0.9175 - val_loss: 0.4295 - val_accuracy: 0.8772
# Epoch 51/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2710 - accuracy: 0.9187 - val_loss: 0.4306 - val_accuracy: 0.8770
# Epoch 52/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2674 - accuracy: 0.9197 - val_loss: 0.4315 - val_accuracy: 0.8774
# Epoch 53/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2638 - accuracy: 0.9207 - val_loss: 0.4313 - val_accuracy: 0.8781
# Epoch 54/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2602 - accuracy: 0.9218 - val_loss: 0.4323 - val_accuracy: 0.8783
# Epoch 55/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2567 - accuracy: 0.9230 - val_loss: 0.4352 - val_accuracy: 0.8781
# Epoch 56/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2532 - accuracy: 0.9239 - val_loss: 0.4344 - val_accuracy: 0.8776
# Epoch 57/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2497 - accuracy: 0.9249 - val_loss: 0.4362 - val_accuracy: 0.8783
# Epoch 58/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2462 - accuracy: 0.9260 - val_loss: 0.4372 - val_accuracy: 0.8782
# Epoch 59/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2432 - accuracy: 0.9267 - val_loss: 0.4380 - val_accuracy: 0.8781
# Epoch 60/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2396 - accuracy: 0.9279 - val_loss: 0.4522 - val_accuracy: 0.8735
# Epoch 61/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2364 - accuracy: 0.9289 - val_loss: 0.4384 - val_accuracy: 0.8788
# Epoch 62/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2332 - accuracy: 0.9298 - val_loss: 0.4410 - val_accuracy: 0.8783
# Epoch 63/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2304 - accuracy: 0.9306 - val_loss: 0.4405 - val_accuracy: 0.8790
# Epoch 64/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2268 - accuracy: 0.9317 - val_loss: 0.4447 - val_accuracy: 0.8782
# Epoch 65/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2241 - accuracy: 0.9325 - val_loss: 0.4478 - val_accuracy: 0.8782
# Epoch 66/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2210 - accuracy: 0.9334 - val_loss: 0.4448 - val_accuracy: 0.8784
# Epoch 67/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2180 - accuracy: 0.9342 - val_loss: 0.4488 - val_accuracy: 0.8776
# Epoch 68/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.2151 - accuracy: 0.9352 - val_loss: 0.4492 - val_accuracy: 0.8789
# Epoch 69/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.2123 - accuracy: 0.9360 - val_loss: 0.4518 - val_accuracy: 0.8780
# Epoch 70/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2093 - accuracy: 0.9370 - val_loss: 0.4526 - val_accuracy: 0.8781
# Epoch 71/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2067 - accuracy: 0.9377 - val_loss: 0.4551 - val_accuracy: 0.8778
# Epoch 72/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2035 - accuracy: 0.9382 - val_loss: 0.4553 - val_accuracy: 0.8787
# Epoch 73/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2011 - accuracy: 0.9391 - val_loss: 0.4553 - val_accuracy: 0.8792
# Epoch 74/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1982 - accuracy: 0.9400 - val_loss: 0.4576 - val_accuracy: 0.8784
# Epoch 75/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1952 - accuracy: 0.9408 - val_loss: 0.4631 - val_accuracy: 0.8778
# Epoch 76/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.1934 - accuracy: 0.9413 - val_loss: 0.4611 - val_accuracy: 0.8784
# Epoch 77/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1902 - accuracy: 0.9424 - val_loss: 0.4650 - val_accuracy: 0.8785
# Epoch 78/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1875 - accuracy: 0.9431 - val_loss: 0.4695 - val_accuracy: 0.8782
# Epoch 79/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1848 - accuracy: 0.9440 - val_loss: 0.4710 - val_accuracy: 0.8774
# Epoch 80/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1832 - accuracy: 0.9446 - val_loss: 0.4713 - val_accuracy: 0.8787
# Epoch 81/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1804 - accuracy: 0.9454 - val_loss: 0.4754 - val_accuracy: 0.8766
# Epoch 82/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1782 - accuracy: 0.9459 - val_loss: 0.4767 - val_accuracy: 0.8771
# Epoch 83/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1756 - accuracy: 0.9470 - val_loss: 0.4790 - val_accuracy: 0.8774
# Epoch 84/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1734 - accuracy: 0.9477 - val_loss: 0.4829 - val_accuracy: 0.8771
# Epoch 85/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1710 - accuracy: 0.9484 - val_loss: 0.4842 - val_accuracy: 0.8781
# Epoch 86/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1686 - accuracy: 0.9491 - val_loss: 0.4881 - val_accuracy: 0.8771
# Epoch 87/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1664 - accuracy: 0.9494 - val_loss: 0.4843 - val_accuracy: 0.8783
# Epoch 88/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1643 - accuracy: 0.9501 - val_loss: 0.4898 - val_accuracy: 0.8777
# Epoch 89/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1621 - accuracy: 0.9506 - val_loss: 0.4920 - val_accuracy: 0.8780
# Epoch 90/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1601 - accuracy: 0.9515 - val_loss: 0.4970 - val_accuracy: 0.8781
# Epoch 91/100
# 125/125 [==============================] - 2s 16ms/step - loss: 0.1577 - accuracy: 0.9521 - val_loss: 0.4988 - val_accuracy: 0.8768
# Epoch 92/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1556 - accuracy: 0.9525 - val_loss: 0.5000 - val_accuracy: 0.8775
# Epoch 93/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1536 - accuracy: 0.9533 - val_loss: 0.5070 - val_accuracy: 0.8766
# Epoch 94/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1515 - accuracy: 0.9540 - val_loss: 0.5146 - val_accuracy: 0.8764
# Epoch 95/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1494 - accuracy: 0.9548 - val_loss: 0.5111 - val_accuracy: 0.8767
# Epoch 96/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1476 - accuracy: 0.9550 - val_loss: 0.5107 - val_accuracy: 0.8768
# Epoch 97/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1454 - accuracy: 0.9557 - val_loss: 0.5157 - val_accuracy: 0.8767
# Epoch 98/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1438 - accuracy: 0.9563 - val_loss: 0.5158 - val_accuracy: 0.8773
# Epoch 99/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1417 - accuracy: 0.9568 - val_loss: 0.5181 - val_accuracy: 0.8771
# Epoch 100/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1401 - accuracy: 0.9573 - val_loss: 0.5218 - val_accuracy: 0.8775
# WARNING:absl:Found untraced functions such as lstm_cell_6_layer_call_fn, lstm_cell_6_layer_call_and_return_conditional_losses, lstm_cell_7_layer_call_fn, lstm_cell_7_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.

# %% [markdown]
# ## Run Inference

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = keras.Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = keras.Input(shape=(latent_dim,))
decoder_state_input_c = keras.Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = keras.Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 378ms/step
# 1/1 [==============================] - 0s 404ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Go.
# Decoded sentence: Va !
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut.
#
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# -
# Input sentence: Run!
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Run.
# Decoded sentence: Filez !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run.
# Decoded sentence: Filez !
